# %%
#import the necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Set the number of columns to display from the dataset
pd.set_option('display.max_rows', 44) # To display all the 44 columns in the dataset
pd.set_option('display.max_columns', 44)

# %% [markdown]
# ### Read the train dataset

# %%
# Copy and paste the file directory
file_path = r"C:\Users\HP\Downloads\digital-green-crop-yield-estimate-challenge20230912-4562-1bbmstk (1)\Train.csv"

# %%
# Use pandas library to read the csv file
df_train = pd.read_csv(file_path)

# %% [markdown]
# ### Performing Exploratory Data Analysis (EDA)

# %%
# Display the first 5 rows
df_train.head()
# Out:
#                 ID District      Block  CultLand  CropCultLand  \
# 0  ID_GTFAC7PEVWQ9  Nalanda  Noorsarai        45            40
# 1  ID_TK40ARLSPOKS  Nalanda     Rajgir        26            26
# 2  ID_1FJY2CRIMLZZ     Gaya      Gurua        10            10
# 3  ID_I3IPXS4DB7NE     Gaya      Gurua        15            15
# 4  ID_4T8YQWXWHB4A  Nalanda  Noorsarai        60            60
#
#                                LandPreparationMethod CropTillageDate  \
# 0               TractorPlough FourWheelTracRotavator      2022-07-20
# 1  WetTillagePuddling TractorPlough FourWheelTrac...      2022-07-18
# 2               TractorPlough FourWheelTracRotavator      2022-06-30
# 3               TractorPlough FourWheelTracRotavator      2022-06-16
# 4                   TractorPlough WetTillagePuddling      2022-07-19
#
#    CropTillageDepth         CropEstMethod RcNursEstDate  \
# 0                 5  Manual_PuddledRandom    2022-06-27
# ...

# %%
# Display the last 5 rows
df_train.tail()
# Out:
#                    ID  District      Block  CultLand  CropCultLand  \
# 3865  ID_7ZZQ6R4XB4FK   Nalanda     Rajgir        28            28
# 3866  ID_PVVDF6LK6FO8  Vaishali      Mahua         5             5
# 3867  ID_RBYVUPRATVMW   Nalanda  Noorsarai        50            45
# 3868  ID_ARE9QWENJNJ2     Jamui     Khaira        20            20
# 3869  ID_KEPOQDTCZC6S     Jamui      Jamui         4             4
#
#                                   LandPreparationMethod CropTillageDate  \
# 3865  WetTillagePuddling TractorPlough FourWheelTrac...      2022-07-02
# 3866  WetTillagePuddling TractorPlough FourWheelTrac...      2022-07-06
# 3867                                      TractorPlough      2022-07-07
# 3868                                      TractorPlough      2022-07-12
# 3869                                      TractorPlough      2022-07-24
#
#       CropTillageDepth           CropEstMethod RcNursEstDate  \
# 3865                 6  LineSowingAfterTillage    2022-06-29
# ...

# %%
# Display the number of unique numbers/values in the train dataset
df_train.nunique()
# Out:
# ID                                    3870
# District                                 4
# Block                                    9
# CultLand                                95
# CropCultLand                            91
# LandPreparationMethod                   43
# CropTillageDate                         78
# CropTillageDepth                         8
# CropEstMethod                            4
# RcNursEstDate                           61
# SeedingSowingTransplanting              62
# SeedlingsPerPit                         21
# NursDetFactor                          125
# TransDetFactor                         155
# TransplantingIrrigationHours            43
# TransplantingIrrigationSource            6
# TransplantingIrrigationPowerSource       3
# TransIrriCost                          100
# StandingWater                           14
# OrgFertilizers                          31
# Ganaura                                 35
# CropOrgFYM                              44
# ...

# %%
# Let get the description of the train datasets
df_train.describe()
# Out:
#           CultLand  CropCultLand  CropTillageDepth  SeedlingsPerPit  \
# count  3870.000000   3870.000000       3870.000000      3581.000000
# mean     28.527907     24.727132          4.488372         2.706507
# std      30.454218     27.994802          1.133044         7.624397
# min       1.000000      1.000000          1.000000         1.000000
# 25%      12.000000     10.000000          4.000000         2.000000
# 50%      20.000000     20.000000          4.000000         2.000000
# 75%      35.000000     30.000000          5.000000         3.000000
# max     800.000000    800.000000          8.000000       442.000000
#
#        TransplantingIrrigationHours  TransIrriCost  StandingWater  \
# count                   3677.000000    2988.000000    3632.000000
# mean                       8.017677     379.726908       3.247522
# std                       42.612470     419.724782       2.207276
# min                        1.000000       1.000000       1.000000
# ...

# %%
# Check other information about the dataset
df_train.info() # Here, you get to know the data type and columns with missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3870 entries, 0 to 3869
# Data columns (total 44 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ID                                  3870 non-null   object
#  1   District                            3870 non-null   object
#  2   Block                               3870 non-null   object
#  3   CultLand                            3870 non-null   int64
#  4   CropCultLand                        3870 non-null   int64
#  5   LandPreparationMethod               3870 non-null   object
#  6   CropTillageDate                     3870 non-null   object
#  7   CropTillageDepth                    3870 non-null   int64
#  8   CropEstMethod                       3870 non-null   object
#  9   RcNursEstDate                       3787 non-null   object
#  10  SeedingSowingTransplanting          3870 non-null   object
# ...

# %% [markdown]
# There are 43 columns in the dataset with many outliers.

# %%
# Let identify the number of missing numbers in the dataset
missing_df_train = df_train.isnull().sum()
print(missing_df_train)
# Out:
# ID                                       0
# District                                 0
# Block                                    0
# CultLand                                 0
# CropCultLand                             0
# LandPreparationMethod                    0
# CropTillageDate                          0
# CropTillageDepth                         0
# CropEstMethod                            0
# RcNursEstDate                           83
# SeedingSowingTransplanting               0
# SeedlingsPerPit                        289
# NursDetFactor                          289
# TransDetFactor                         289
# TransplantingIrrigationHours           193
# TransplantingIrrigationSource          115
# TransplantingIrrigationPowerSource     503
# TransIrriCost                          882
# StandingWater                          238
# OrgFertilizers                        1335
# Ganaura                               2417
# CropOrgFYM                            2674
# ...

# %%
print(df_train.columns)
print('\n')
print(len(df_train.columns))
# Out:
# Index(['ID', 'District', 'Block', 'CultLand', 'CropCultLand',
#        'LandPreparationMethod', 'CropTillageDate', 'CropTillageDepth',
#        'CropEstMethod', 'RcNursEstDate', 'SeedingSowingTransplanting',
#        'SeedlingsPerPit', 'NursDetFactor', 'TransDetFactor',
#        'TransplantingIrrigationHours', 'TransplantingIrrigationSource',
#        'TransplantingIrrigationPowerSource', 'TransIrriCost', 'StandingWater',
#        'OrgFertilizers', 'Ganaura', 'CropOrgFYM', 'PCropSolidOrgFertAppMethod',
#        'NoFertilizerAppln', 'CropbasalFerts', 'BasalDAP', 'BasalUrea',
#        'MineralFertAppMethod', 'FirstTopDressFert', '1tdUrea', '1appDaysUrea',
#        '2tdUrea', '2appDaysUrea', 'MineralFertAppMethod.1', 'Harv_method',
#        'Harv_date', 'Harv_hand_rent', 'Threshing_date', 'Threshing_method',
#        'Residue_length', 'Residue_perc', 'Stubble_use', 'Acre', 'Yield'],
#       dtype='object')
#
#
# 44

# %%
# Let's visualize only two columns 'CultLand' and 'CropCultLand'
plt.plot(df_train.CultLand,
        df_train.CropCultLand,
        ls = '', marker='o')
plt.show()

# %% [markdown]
# ### Read the test dataset

# %%
test_dir = r"C:\Users\HP\Downloads\digital-green-crop-yield-estimate-challenge20230912-4562-1bbmstk (1)\Test.csv"

# %%
df_test = pd.read_csv(test_dir, delimiter = ',')

# %%
# display the first five rows
df_test.head()
# Out:
#                 ID  District   Block  CultLand  CropCultLand  \
# 0  ID_F9XXEXN2ADR2     Jamui  Khaira        20            13
# 1  ID_SO3VW2X4QO93     Jamui  Khaira        25            25
# 2  ID_UKUQ7JM8E894   Nalanda  Rajgir        30            30
# 3  ID_QUISMWEZR2H4  Vaishali   Mahua        15            10
# 4  ID_25JGI455VKCZ   Nalanda  Rajgir        30            10
#
#                                LandPreparationMethod CropTillageDate  \
# 0                                      TractorPlough      2022-07-24
# 1                                      TractorPlough      2022-07-24
# 2  WetTillagePuddling TractorPlough FourWheelTrac...      2022-07-07
# 3  WetTillagePuddling TractorPlough BullockPlough...      2022-07-04
# 4  WetTillagePuddling TractorPlough FourWheelTrac...      2022-07-21
#
#    CropTillageDepth         CropEstMethod RcNursEstDate  \
# 0                 4    Manual_PuddledLine    2022-07-03
# 1                 5  Manual_PuddledRandom    2022-07-08
# ...

# %%
# display the last five rows
df_test.tail()
# Out:
#                    ID  District      Block  CultLand  CropCultLand  \
# 1285  ID_6MMECMX3B728     Jamui     Khaira        20            16
# 1286  ID_GZ9YGWCLLMKN  Vaishali      Mahua        25            14
# 1287  ID_01YVA2LJVYBR  Vaishali     Garoul        10             3
# 1288  ID_YQRL2IOUU4SZ     Jamui      Jamui        10            10
# 1289  ID_VAX2N8ELPEZE   Nalanda  Noorsarai        15            15
#
#                                   LandPreparationMethod CropTillageDate  \
# 1285                                      TractorPlough      2022-07-23
# 1286  WetTillagePuddling TractorPlough FourWheelTrac...      2022-07-07
# 1287                                      TractorPlough      2022-07-06
# 1288                        TractorPlough BullockPlough      2022-07-22
# 1289               TractorPlough FourWheelTracRotavator      2022-07-08
#
#       CropTillageDepth         CropEstMethod RcNursEstDate  \
# 1285                 4    Manual_PuddledLine    2022-07-05
# ...

# %%
# check the number of unique values in the dataset
print(df_test.nunique())
# Out:
# ID                                    1290
# District                                 4
# Block                                   10
# CultLand                                70
# CropCultLand                            67
# LandPreparationMethod                   30
# CropTillageDate                         75
# CropTillageDepth                         8
# CropEstMethod                            4
# RcNursEstDate                           60
# SeedingSowingTransplanting              61
# SeedlingsPerPit                         18
# NursDetFactor                           90
# TransDetFactor                         104
# TransplantingIrrigationHours            34
# TransplantingIrrigationSource            5
# TransplantingIrrigationPowerSource       2
# TransIrriCost                           76
# StandingWater                           14
# OrgFertilizers                          18
# Ganaura                                 27
# CropOrgFYM                              34
# ...

# %%
# check the description of the dataset
df_test.describe()
# Out:
#           CultLand  CropCultLand  CropTillageDepth  SeedlingsPerPit  \
# count  1290.000000   1290.000000       1290.000000      1187.000000
# mean     29.199225     25.537984          4.434109         2.598147
# std      24.640405     23.290966          1.139903         2.055166
# min       1.000000      1.000000          1.000000         1.000000
# 25%      12.000000     10.000000          4.000000         2.000000
# 50%      21.000000     20.000000          4.000000         2.000000
# 75%      40.000000     30.000000          5.000000         3.000000
# max     200.000000    200.000000          8.000000        20.000000
#
#        TransplantingIrrigationHours  TransIrriCost  StandingWater     Ganaura  \
# count                   1213.000000     973.000000    1211.000000  495.000000
# mean                       8.352020     405.018499       3.267547   28.292929
# std                       37.107536     440.257325       2.240741  116.253149
# ...

# %%
# CultLand and CropCultLand seems to have the highest values and so, they can be plotted
# plotting the two features
plt.figure(figsize=(15,4))
plt.plot(
    df_test.CultLand,
    df_test.CropCultLand,
    ls='', marker='o',
)
plt.show()

# %% [markdown]
# ### Feature engineering

# %% [markdown]
# We want to identify part of the features with categorical variables. Here, we firstly check the columns and identify those with such values.

# %%
df_test.columns
# Out:
# Index(['ID', 'District', 'Block', 'CultLand', 'CropCultLand',
#        'LandPreparationMethod', 'CropTillageDate', 'CropTillageDepth',
#        'CropEstMethod', 'RcNursEstDate', 'SeedingSowingTransplanting',
#        'SeedlingsPerPit', 'NursDetFactor', 'TransDetFactor',
#        'TransplantingIrrigationHours', 'TransplantingIrrigationSource',
#        'TransplantingIrrigationPowerSource', 'TransIrriCost', 'StandingWater',
#        'OrgFertilizers', 'Ganaura', 'CropOrgFYM', 'PCropSolidOrgFertAppMethod',
#        'NoFertilizerAppln', 'CropbasalFerts', 'BasalDAP', 'BasalUrea',
#        'MineralFertAppMethod', 'FirstTopDressFert', '1tdUrea', '1appDaysUrea',
#        '2tdUrea', '2appDaysUrea', 'MineralFertAppMethod.1', 'Harv_method',
#        'Harv_date', 'Harv_hand_rent', 'Threshing_date', 'Threshing_method',
#        'Residue_length', 'Residue_perc', 'Stubble_use', 'Acre'],
#       dtype='object')

# %%
# Dropping some features from the test dataset
df_test.drop('LandPreparationMethod', axis=1, inplace=True)
df_test.drop('CropTillageDate', axis=1, inplace=True)
df_test.drop('RcNursEstDate', axis=1, inplace=True)
df_test.drop('Harv_date', axis=1, inplace=True)
df_test.drop('Threshing_date', axis=1, inplace=True)
df_test.drop('SeedingSowingTransplanting', axis=1, inplace=True)
df_test.drop('NursDetFactor', axis=1, inplace=True)
df_test.drop('TransDetFactor', axis=1, inplace=True)

# %%
# Preprocessing the dataset
# We do the same for the train dataset
# this is because we want use the pattern of the train dataset and use it to predict the test dataset
df_train.drop('LandPreparationMethod', axis=1, inplace=True)
df_train.drop('CropTillageDate', axis=1, inplace=True)
df_train.drop('RcNursEstDate', axis=1, inplace=True)
df_train.drop('Harv_date', axis=1, inplace=True)
df_train.drop('Threshing_date', axis=1, inplace=True)
df_train.drop('SeedingSowingTransplanting', axis=1, inplace=True)
df_train.drop('NursDetFactor', axis=1, inplace=True)
df_train.drop('TransDetFactor', axis=1, inplace=True)

# %%
# Check whether they have been dropped
print(df_test.info())
print(df_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1290 entries, 0 to 1289
# Data columns (total 35 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ID                                  1290 non-null   object
#  1   District                            1290 non-null   object
#  2   Block                               1290 non-null   object
#  3   CultLand                            1290 non-null   int64
#  4   CropCultLand                        1290 non-null   int64
#  5   CropTillageDepth                    1290 non-null   int64
#  6   CropEstMethod                       1290 non-null   object
#  7   SeedlingsPerPit                     1187 non-null   float64
#  8   TransplantingIrrigationHours        1213 non-null   float64
#  9   TransplantingIrrigationSource       1244 non-null   object
#  10  TransplantingIrrigationPowerSource  1119 non-null   object
# ...

# %%
df_test['TransplantingIrrigationSource'].unique()
# Out:
# array(['Boring', 'Canal', nan, 'Rainfed', 'Pond', 'TubeWell'],
#       dtype=object)

# %%
# Let's identify the unique values each of the categorical variables
# identify and list the features
test_cats_featues = ['District', 'Block', 'CropEstMethod', 'Harv_method', 'TransplantingIrrigationPowerSource',
                     'TransplantingIrrigationSource', 'OrgFertilizers', 'PCropSolidOrgFertAppMethod', 
                     'MineralFertAppMethod','Threshing_method', 'Stubble_use']

# check the unique values in them
for test_categorical_feats in test_cats_featues:
    print(df_test[test_categorical_feats].unique())
# Out:
# ['Jamui' 'Nalanda' 'Vaishali' 'Gaya']
# ['Khaira' 'Rajgir' 'Mahua' 'Gurua' 'Garoul' 'Noorsarai' 'Jamui'
#  'Chehrakala' 'Wazirganj' 'Lohra']
# ['Manual_PuddledLine' 'Manual_PuddledRandom' 'LineSowingAfterTillage'
#  'Broadcasting']
# ['hand' 'machine']
# ['Diesel' nan 'Electric']
# ['Boring' 'Canal' nan 'Rainfed' 'Pond' 'TubeWell']
# ['FYM' nan 'Ganaura' 'Ganaura FYM Ghanajeevamrit'
#  'Ganaura FYM VermiCompost' 'Ganaura FYM' 'FYM VermiCompost' 'FYM Ganaura'
#  'VermiCompost' 'FYM Ganaura Ghanajeevamrit' 'VermiCompost FYM'
#  'Ganaura Ghanajeevamrit' 'Ghanajeevamrit'
#  'Ganaura Ghanajeevamrit FYM Pranamrit'
#  'Ganaura FYM Ghanajeevamrit VermiCompost' 'PoultryManure'
#  'Ganaura VermiCompost FYM' 'Pranamrit Ganaura Ghanajeevamrit'
#  'FYM Ghanajeevamrit Ganaura']
# ['SoilApplied' nan 'Broadcasting' 'RootApplication' 'Spray']
# ['Broadcasting' 'SoilApplied' 'RootApplication' 'Spray']
# ['hand' 'machine']
# ['plowed_in_soil' 'burned']

# %%
# df_test.head()

# %%
# Let's use the label encoder for features with only two categorical variables
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df_test['Harv_method'] = le.fit_transform(df_test['Harv_method']) # 'hand' is encoded as 0 and 'machine' as 1 
df_test['Threshing_method'] = le.fit_transform(df_test['Threshing_method']) # 'hand' is encoded as 0 and 'machine' as 1 
df_test['Stubble_use'] = le.fit_transform(df_test['Stubble_use']) # 'plowed_in_soil' is encoded as 1 and 'burned' as 0
df_test.head()
# Out:
#                 ID  District  Block  CultLand  CropCultLand  CropTillageDepth  \
# 0  ID_F9XXEXN2ADR2         1      1        20            13                 4
# 1  ID_SO3VW2X4QO93         1      1        25            25                 5
# 2  ID_UKUQ7JM8E894         2      2        30            30                 5
# 3  ID_QUISMWEZR2H4         3      3        15            10                 5
# 4  ID_25JGI455VKCZ         2      2        30            10                 3
#
#    CropEstMethod  SeedlingsPerPit  TransplantingIrrigationHours  \
# 0              1              1.0                           2.0
# 1              2              4.0                           2.0
# 2              2              2.0                           4.0
# 3              2              2.0                           2.0
# 4              2              1.0                           6.0
#
#    TransplantingIrrigationSource  TransplantingIrrigationPowerSource  \
# ...

# %%
# Let's do the same for the train dataset
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df_train['Harv_method'] = le.fit_transform(df_train['Harv_method']) # 'hand' is encoded as 0 and 'machine' as 1 
df_train['Threshing_method'] = le.fit_transform(df_train['Threshing_method']) # 'hand' is encoded as 0 and 'machine' as 1 
df_train['Stubble_use'] = le.fit_transform(df_train['Stubble_use']) # 'plowed_in_soil' is encoded as 1 and 'burned' as 0
df_train.head()
# Out:
#                 ID  District  Block  CultLand  CropCultLand  CropTillageDepth  \
# 0  ID_GTFAC7PEVWQ9         2      6        45            40                 5
# 1  ID_TK40ARLSPOKS         2      2        26            26                 5
# 2  ID_1FJY2CRIMLZZ         4      4        10            10                 6
# 3  ID_I3IPXS4DB7NE         4      4        15            15                 6
# 4  ID_4T8YQWXWHB4A         2      6        60            60                 4
#
#    CropEstMethod  SeedlingsPerPit  TransplantingIrrigationHours  \
# 0              2              2.0                           5.0
# 1              2              2.0                           5.0
# 2              2              2.0                           4.0
# 3              2              2.0                           NaN
# 4              2              2.0                           9.0
#
#   TransplantingIrrigationSource TransplantingIrrigationPowerSource  \
# ...

# %%
# Let's map the features with more than two variables using lambda function
map_discrict = {'Jamui':1, 'Nalanda':2, 'Vaishali':3, 'Gaya':4}
map_block = {'Khaira':1, 'Rajgir':2, 'Mahua':3, 'Gurua':4, 'Garoul':5, 
             'Noorsarai':6, 'Jamui':7, 'Chehrakala':8, 'Wazirganj':9, 'Lohra':10}
map_CropEstMethod = {'Manual_PuddledLine':1, 'Manual_PuddledRandom':2, 'LineSowingAfterTillage':3, 'Broadcasting':4}
map_transSource = {'nan':0,'Boring':1, 'Canal':2, 'Rainfed':3, 'Pond':4, 'TubeWell':5}
map_transPowerSource = {'nan':0, 'Diesel':1, 'Electric':2}
map_orgFertilizer = {'nan': 0, 'FYM':1, 'Ganaura':2, 'Ganaura FYM Ghanajeevamrit':3,
 'Ganaura FYM VermiCompost':4, 'Ganaura FYM':5, 'FYM VermiCompost':6,'FYM Ganaura':7,
 'VermiCompost':8, 'FYM Ganaura Ghanajeevamrit':9, 'VermiCompost FYM':10,
 'Ganaura Ghanajeevamrit':11, 'Ghanajeevamrit':12, 'Ganaura Ghanajeevamrit FYM Pranamrit':13,
 'Ganaura FYM Ghanajeevamrit VermiCompost':14, 'PoultryManure':15, 'Ganaura VermiCompost FYM':16,
'Pranamrit Ganaura Ghanajeevamrit':17, 'FYM Ghanajeevamrit Ganaura':18}
map_PCropSolid = {'nan':0, 4:4, 'SoilApplied':1, 'RootApplication':2, 'Spray': 3}
map_MineralFertApp = {'Broadcasting':1, 'SoilApplied':2, 'RootApplication':3, 'Spray':4}
map_FirstFert = {'nan':0,'Urea':1, 'DAP Urea':2, 'Urea DAP':3, 'NPKS Urea':4, 'NPK':5, 'Urea NPKS':6,
 'DAP NPK Urea':7, 'DAP NPKS':8, 'Urea NPK':9, 'DAP NPK':10, 'Urea SSP':11, 'NPK Urea':12,'Other Urea':13}
map_MineralFert1 = {'nan':0,'Broadcasting':1, 'RootApplication':2,  'SoilApplied':3}
map_list = [map_discrict, map_block, map_CropEstMethod, map_transSource, map_transPowerSource,
            map_orgFertilizer, map_PCropSolid, map_MineralFertApp, map_FirstFert, map_MineralFert1]
for df_test_map in map_list:
    df_test = df_test.applymap(lambda s: df_test_map.get(s) if s in df_test_map else s)
df_test.head(3)
# Out:
#                 ID  District  Block  CultLand  CropCultLand  CropTillageDepth  \
# 0  ID_F9XXEXN2ADR2         1      1        20            13                 4
# 1  ID_SO3VW2X4QO93         1      1        25            25                 5
# 2  ID_UKUQ7JM8E894         2      2        30            30                 5
#
#    CropEstMethod  SeedlingsPerPit  TransplantingIrrigationHours  \
# 0              1              1.0                           2.0
# 1              2              4.0                           2.0
# 2              2              2.0                           4.0
#
#    TransplantingIrrigationSource  TransplantingIrrigationPowerSource  \
# 0                            1.0                                 1.0
# 1                            2.0                                 NaN
# 2                            2.0                                 NaN
#
#    TransIrriCost  StandingWater  OrgFertilizers  Ganaura  CropOrgFYM  \
# ...

# %%
# Doing the same for the train dataset
# Let's map the features with more than two variables using lambda function
map_discrict = {'Jamui':1, 'Nalanda':2, 'Vaishali':3, 'Gaya':4}
map_block = {'Khaira':1, 'Rajgir':2, 'Mahua':3, 'Gurua':4, 'Garoul':5, 
             'Noorsarai':6, 'Jamui':7, 'Chehrakala':8, 'Wazirganj':9, 'Lohra':10}
map_CropEstMethod = {'Manual_PuddledLine':1, 'Manual_PuddledRandom':2, 'LineSowingAfterTillage':3, 'Broadcasting':4}
map_transSource = {'nan':0,'Boring':1, 'Canal':2, 'Rainfed':3, 'Pond':4, 'TubeWell':5}
map_transPowerSource = {'nan':0, 'Diesel':1, 'Electric':2}
map_orgFertilizer = {'nan': 0, 'FYM':1, 'Ganaura':2, 'Ganaura FYM Ghanajeevamrit':3,
 'Ganaura FYM VermiCompost':4, 'Ganaura FYM':5, 'FYM VermiCompost':6,'FYM Ganaura':7,
 'VermiCompost':8, 'FYM Ganaura Ghanajeevamrit':9, 'VermiCompost FYM':10,
 'Ganaura Ghanajeevamrit':11, 'Ghanajeevamrit':12, 'Ganaura Ghanajeevamrit FYM Pranamrit':13,
 'Ganaura FYM Ghanajeevamrit VermiCompost':14, 'PoultryManure':15, 'Ganaura VermiCompost FYM':16,
'Pranamrit Ganaura Ghanajeevamrit':17, 'FYM Ghanajeevamrit Ganaura':18}
map_PCropSolid = {'nan':0, 4:4, 'SoilApplied':1, 'RootApplication':2, 'Spray': 3}
map_MineralFertApp = {'Broadcasting':1, 'SoilApplied':2, 'RootApplication':3, 'Spray':4}
map_FirstFert = { 'nan':0,'Urea':1, 'DAP Urea':2, 'Urea DAP':3, 'DAP':4, 'NPKS Urea':4, 'NPK':5, 'Urea NPKS':6,
 'DAP NPK Urea':7, 'DAP NPKS':8, 'Urea NPK':9, 'DAP NPK':10, 'Urea SSP':11, 'NPK Urea':12,'Other Urea':13}
map_MineralFert1 = {'nan':0,'Broadcasting':1, 'RootApplication':2,  'SoilApplied':3}
train_map_list = [map_discrict, map_block, map_CropEstMethod, map_transSource, map_transPowerSource,
            map_orgFertilizer, map_PCropSolid, map_MineralFertApp, map_FirstFert, map_MineralFert1]
            
for df_train_map in train_map_list:
    df_train = df_train.applymap(lambda s: df_train_map.get(s) if s in df_train_map else s)
df_train.head()
# Out:
#                 ID  District  Block  CultLand  CropCultLand  CropTillageDepth  \
# 0  ID_GTFAC7PEVWQ9         2      6        45            40                 5
# 1  ID_TK40ARLSPOKS         2      2        26            26                 5
# 2  ID_1FJY2CRIMLZZ         4      4        10            10                 6
# 3  ID_I3IPXS4DB7NE         4      4        15            15                 6
# 4  ID_4T8YQWXWHB4A         2      6        60            60                 4
#
#    CropEstMethod  SeedlingsPerPit  TransplantingIrrigationHours  \
# 0              2              2.0                      5.000000
# 1              2              2.0                      5.000000
# 2              2              2.0                      4.000000
# 3              2              2.0                      8.017677
# 4              2              2.0                      9.000000
#
#   TransplantingIrrigationSource TransplantingIrrigationPowerSource  \
# ...

# %%
df_test.describe()
# Out:
#           CultLand  CropCultLand  CropTillageDepth  SeedlingsPerPit  \
# count  1290.000000   1290.000000       1290.000000      1187.000000
# mean     29.199225     25.537984          4.434109         2.598147
# std      24.640405     23.290966          1.139903         2.055166
# min       1.000000      1.000000          1.000000         1.000000
# 25%      12.000000     10.000000          4.000000         2.000000
# 50%      21.000000     20.000000          4.000000         2.000000
# 75%      40.000000     30.000000          5.000000         3.000000
# max     200.000000    200.000000          8.000000        20.000000
#
#        TransplantingIrrigationHours  TransIrriCost  StandingWater     Ganaura  \
# count                   1213.000000     973.000000    1211.000000  495.000000
# mean                       8.352020     405.018499       3.267547   28.292929
# std                       37.107536     440.257325       2.240741  116.253149
# ...

# %%
# We are dropping features with lot of missing numbers
# df_test.drop('2tdUrea', axis=1, inplace=True)
# df_test.drop('2appDaysUrea', axis=1, inplace=True)
# df_test.drop('TransIrriCost', axis=1, inplace=True)

# %%
df_train.describe()
# Out:
#           District        Block     CultLand  CropCultLand  CropTillageDepth  \
# count  3870.000000  3870.000000  3870.000000   3870.000000       3870.000000
# mean      2.256589     3.265116    28.527907     24.727132          4.488372
# std       1.033455     2.422539    30.454218     27.994802          1.133044
# min       1.000000     1.000000     1.000000      1.000000          1.000000
# 25%       1.000000     1.000000    12.000000     10.000000          4.000000
# 50%       2.000000     2.000000    20.000000     20.000000          4.000000
# 75%       3.000000     4.000000    35.000000     30.000000          5.000000
# max       4.000000     9.000000   800.000000    800.000000          8.000000
#
#        CropEstMethod  SeedlingsPerPit  TransplantingIrrigationHours  \
# count    3870.000000      3870.000000                   3870.000000
# mean        2.035401         2.706507                      8.017677
# std         0.445578         7.334114                     41.536040
# ...

# %%
# Convert the categorical variables to numerical variables
# df_test = pd.get_dummies(df_test, columns=test_cats_featues, drop_first = True)
# df_test.head()

# %%
# df_train['TransplantingIrrigationSource'].unique()

# %%
print(df_test.columns, "\n", df_train.columns)
print("\n", len(df_test.columns), "\n", len(df_train.columns))
print()
# Out:
# Index(['ID', 'District', 'Block', 'CultLand', 'CropCultLand',
#        'CropTillageDepth', 'CropEstMethod', 'SeedlingsPerPit',
#        'TransplantingIrrigationHours', 'TransplantingIrrigationSource',
#        'TransplantingIrrigationPowerSource', 'TransIrriCost', 'StandingWater',
#        'OrgFertilizers', 'Ganaura', 'CropOrgFYM', 'PCropSolidOrgFertAppMethod',
#        'NoFertilizerAppln', 'CropbasalFerts', 'BasalDAP', 'BasalUrea',
#        'MineralFertAppMethod', 'FirstTopDressFert', '1tdUrea', '1appDaysUrea',
#        '2tdUrea', '2appDaysUrea', 'MineralFertAppMethod.1', 'Harv_method',
#        'Harv_hand_rent', 'Threshing_method', 'Residue_length', 'Residue_perc',
#        'Stubble_use', 'Acre'],
#       dtype='object')
#  Index(['ID', 'District', 'Block', 'CultLand', 'CropCultLand',
#        'CropTillageDepth', 'CropEstMethod', 'SeedlingsPerPit',
#        'TransplantingIrrigationHours', 'TransplantingIrrigationSource',
# ...

# %% [markdown]
# ### Treating missing values in both train and test dataset

# %%
# We are going to define the features for the training
features = ['District', 'Block', 'CultLand', 'CropCultLand',
       'CropTillageDepth', 'CropEstMethod', 'SeedlingsPerPit',
       'TransplantingIrrigationHours', 'TransplantingIrrigationSource',
       'TransplantingIrrigationPowerSource', 'TransIrriCost', 'StandingWater',
       'OrgFertilizers', 'Ganaura', 'CropOrgFYM', 'PCropSolidOrgFertAppMethod',
       'NoFertilizerAppln', 'CropbasalFerts', 'BasalDAP', 'BasalUrea',
       'MineralFertAppMethod', 'FirstTopDressFert', '1tdUrea', '1appDaysUrea',
       '2tdUrea', '2appDaysUrea', 'MineralFertAppMethod.1', 'Harv_method',
       'Harv_hand_rent', 'Threshing_method', 'Residue_length', 'Residue_perc',
       'Stubble_use', 'Acre']
print(len(features))
# Out:
# 34

# %%
# Let's check the columns with missing values
print(df_train[features].info())
print(df_test[features].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3870 entries, 0 to 3869
# Data columns (total 34 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   District                            3870 non-null   int64
#  1   Block                               3870 non-null   int64
#  2   CultLand                            3870 non-null   int64
#  3   CropCultLand                        3870 non-null   int64
#  4   CropTillageDepth                    3870 non-null   int64
#  5   CropEstMethod                       3870 non-null   int64
#  6   SeedlingsPerPit                     3870 non-null   float64
#  7   TransplantingIrrigationHours        3870 non-null   float64
#  8   TransplantingIrrigationSource       3755 non-null   object
#  9   TransplantingIrrigationPowerSource  3367 non-null   object
#  10  TransIrriCost                       3870 non-null   float64
# ...

# %%
print(df_train[features].isnull().sum())
print("\n")
print("For test dataset", "\n")
print(df_test[features].isnull().sum())
# Out:
# District                                 0
# Block                                    0
# CultLand                                 0
# CropCultLand                             0
# CropTillageDepth                         0
# CropEstMethod                            0
# SeedlingsPerPit                          0
# TransplantingIrrigationHours             0
# TransplantingIrrigationSource          115
# TransplantingIrrigationPowerSource     503
# TransIrriCost                            0
# StandingWater                            0
# OrgFertilizers                        1335
# Ganaura                                  0
# CropOrgFYM                               0
# PCropSolidOrgFertAppMethod            1337
# NoFertilizerAppln                        0
# CropbasalFerts                         188
# BasalDAP                                 0
# BasalUrea                                0
# MineralFertAppMethod                     0
# FirstTopDressFert                      485
# ...

# %% [markdown]
# #### Missing values in the train
# 1. SeedlingsPerPit (3581/3870)
# 1. TransplantingIrrigationHours (3677/3870)
# 1. TransplantingIrrigationSource
# 1. TransplantingIrrigationSource          115
# 1. TransplantingIrrigationPowerSource     503
# 1. TransIrriCost                          882
# 1. StandingWater                          238
# 1. OrgFertilizers                        1335
# 1. Ganaura                               2417
# 1. CropOrgFYM                            2674
# 1. PCropSolidOrgFertAppMethod            1337
# 1. CropbasalFerts                         188
# 1. BasalDAP                               543
# 1. BasalUrea                             1704
# 1. FirstTopDressFert                      485
# 1. 1tdUrea                                556
# 1. 1appDaysUrea                           556
# 1. 2tdUrea                               2694
# 1. 2appDaysUrea                          2700
# 1. MineralFertAppMethod.1                 481
# 1. Harv_hand_rent                         252
#
# #### Missing values in the test
# The same goes for the test dataset
#
# We will fill the missing numbers with mean values of the column

# %%
# Fill in missing values with the mean()
df_train['SeedlingsPerPit'] = df_train['SeedlingsPerPit'].fillna(df_train['SeedlingsPerPit'].mean())
df_train['TransplantingIrrigationHours'] = df_train['TransplantingIrrigationHours'].fillna(df_train["TransplantingIrrigationHours"].mean())
#df_train['TransplantingIrrigationSource'] = df_train['TransplantingIrrigationSource'].fillna(df_train["TransplantingIrrigationSource"].mean())
#df_train['TransplantingIrrigationPowerSource'] = df_train['TransplantingIrrigationPowerSource'].fillna(df_train["TransplantingIrrigationPowerSource"].mean())
df_train['TransIrriCost'] = df_train['TransIrriCost'].fillna(df_train['TransIrriCost'].mean())
df_train['StandingWater'] = df_train['StandingWater'].fillna(df_train["StandingWater"].mean())
#df_train['OrgFertilizers'] = df_train['OrgFertilizers'].fillna(df_train["OrgFertilizers"].mean())
df_train['Ganaura'] = df_train['Ganaura'].fillna(df_train["Ganaura"].mean())
df_train['CropOrgFYM'] = df_train['CropOrgFYM'].fillna(df_train["CropOrgFYM"].mean())
# df_train['PCropSolidOrgFertAppMethod'] = df_train['PCropSolidOrgFertAppMethod'].fillna(df_train['PCropSolidOrgFertAppMethod'].mean())
#df_train['CropbasalFerts'] = df_train['CropbasalFerts'].fillna(df_train["CropbasalFerts"].mean())
df_train['BasalDAP'] = df_train['BasalDAP'].fillna(df_train["BasalDAP"].mean())
df_train['BasalUrea'] = df_train['BasalUrea'].fillna(df_train["BasalUrea"].mean())    
df_train['FirstTopDressFert'] = df_train['FirstTopDressFert'].fillna(df_train["FirstTopDressFert"].mean())
df_train['1tdUrea'] = df_train['1tdUrea'].fillna(df_train["1tdUrea"].mean())
df_train['1appDaysUrea'] = df_train['1appDaysUrea'].fillna(df_train['1appDaysUrea'].mean())
df_train['2tdUrea'] = df_train['2tdUrea'].fillna(df_train["2tdUrea"].mean())
df_train['2appDaysUrea'] = df_train['2appDaysUrea'].fillna(df_train["2appDaysUrea"].mean())
df_train['MineralFertAppMethod.1'] = df_train['MineralFertAppMethod.1'].fillna(df_train["MineralFertAppMethod.1"].mean())    
df_train['Harv_hand_rent'] = df_train['Harv_hand_rent'].fillna(df_train["Harv_hand_rent"].mean())

# %%
df_train['MineralFertAppMethod.1'].unique()
# Out:
# array([4.        , 2.        , 3.92151077, 1.        ])

# %%
# Fill in missing values with the mean() for the test dataset
df_test['SeedlingsPerPit'] = df_test['SeedlingsPerPit'].fillna(df_test['SeedlingsPerPit'].mean())
df_test['TransplantingIrrigationHours'] = df_test['TransplantingIrrigationHours'].fillna(df_test["TransplantingIrrigationHours"].mean())
# df_test['TransplantingIrrigationSource'] = df_test['TransplantingIrrigationSource'].fillna(df_test["TransplantingIrrigationSource"].mean())
# df_test['TransplantingIrrigationPowerSource'] = df_test['TransplantingIrrigationPowerSource'].fillna(df_test["TransplantingIrrigationPowerSource"].mean())
df_test['TransIrriCost'] = df_test['TransIrriCost'].fillna(df_test['TransIrriCost'].mean())
df_test['StandingWater'] = df_test['StandingWater'].fillna(df_test["StandingWater"].mean())
df_test['OrgFertilizers'] = df_test['OrgFertilizers'].fillna(df_test["OrgFertilizers"].mean())
df_test['Ganaura'] = df_test['Ganaura'].fillna(df_test["Ganaura"].mean())
df_test['CropOrgFYM'] = df_test['CropOrgFYM'].fillna(df_test["CropOrgFYM"].mean())
df_test['PCropSolidOrgFertAppMethod'] = df_test['PCropSolidOrgFertAppMethod'].fillna(df_test['PCropSolidOrgFertAppMethod'].mean())
df_test['CropbasalFerts'] = df_test['CropbasalFerts'].fillna(df_test["CropbasalFerts"].mean())
df_test['BasalDAP'] = df_test['BasalDAP'].fillna(df_test["BasalDAP"].mean())
df_test['BasalUrea'] = df_test['BasalUrea'].fillna(df_test["BasalUrea"].mean())    
df_test['FirstTopDressFert'] = df_test['FirstTopDressFert'].fillna(df_test["FirstTopDressFert"].mean())
df_test['1tdUrea'] = df_test['1tdUrea'].fillna(df_test["1tdUrea"].mean())
df_test['1appDaysUrea'] = df_test['1appDaysUrea'].fillna(df_test['1appDaysUrea'].mean())
df_test['2tdUrea'] = df_test['2tdUrea'].fillna(df_test["2tdUrea"].mean())
df_test['2appDaysUrea'] = df_test['2appDaysUrea'].fillna(df_test["2appDaysUrea"].mean())
df_test['MineralFertAppMethod.1'] = df_test['MineralFertAppMethod.1'].fillna(df_test["MineralFertAppMethod.1"].mean())    
df_test['Harv_hand_rent'] = df_test['Harv_hand_rent'].fillna(df_test["Harv_hand_rent"].mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 12
#      10 df_test['CropOrgFYM'] = df_test['CropOrgFYM'].fillna(df_test["CropOrgFYM"].mean())
#      11 df_test['PCropSolidOrgFertAppMethod'] = df_test['PCropSolidOrgFertAppMethod'].fillna(df_test['PCropSolidOrgFertAppMethod'].mean())
# ---> 12 df_test['CropbasalFerts'] = df_test['CropbasalFerts'].fillna(df_test["CropbasalFerts"].mean())
#      13 df_test['BasalDAP'] = df_test['BasalDAP'].fillna(df_test["BasalDAP"].mean())
#      14 df_test['BasalUrea'] = df_test['BasalUrea'].fillna(df_test["BasalUrea"].mean())
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11847, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11829 @doc(
#   11830     _num_doc,
#   11831     desc="Return the mean of the values over the requested axis.",
#    (...)
# ...

# %%
# Let's check again
print(df_train[features].info())
print(df_test[features].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3870 entries, 0 to 3869
# Data columns (total 34 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   District                            3870 non-null   int64
#  1   Block                               3870 non-null   int64
#  2   CultLand                            3870 non-null   int64
#  3   CropCultLand                        3870 non-null   int64
#  4   CropTillageDepth                    3870 non-null   int64
#  5   CropEstMethod                       3870 non-null   int64
#  6   SeedlingsPerPit                     3870 non-null   float64
#  7   TransplantingIrrigationHours        3870 non-null   float64
#  8   TransplantingIrrigationSource       3755 non-null   object
#  9   TransplantingIrrigationPowerSource  3367 non-null   object
#  10  TransIrriCost                       3870 non-null   float64
# ...

# %%
# Let's check the predicted column of the training dataset
print(len(df_train['Yield']))
# Out:
# 3870

# %% [markdown]
# ### Machine Learning model (Multi-layer Perceptron classifier)

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.datasets import make_classification
y_train = df_train["Yield"]

features = features

X_train = df_train[features]
X_test = df_test[features]

# %%
# from sklearn.ensemble import RandomForestRegressor
# model = RandomForestRegressor(random_state=0)

# %%
model = MLPRegressor(hidden_layer_sizes=34, 
                     activation='relu', 
                     solver='adam',
                     verbose=True,
                     batch_size='auto', 
                     alpha=0.0001,
                     max_iter=1000, 
                     random_state=0)

# %%
# X_train, y_train = make_classification(n_samples=100, n_features=13, random_state=1)

# %%
# print(X.shape())
# X_test = X_test.values
X_train = X_train.values

# %%
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[188], line 1
# ----> 1 model.fit(X_train, y_train)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:753, in BaseMultilayerPerceptron.fit(self, X, y)
#     735 @_fit_context(prefer_skip_nested_validation=True)
#     736 def fit(self, X, y):
#     737     """Fit the model to data matrix X and target(s) y.
#     738
#     739     Parameters
#    (...)
# ...

# %%
# NN predictions 
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([0.92, 0.92, 0.86, ..., 0.86, 0.92, 0.86])

# %%
output = pd.DataFrame({'ID': df_test.ID, 'Yield': y_pred})
output.to_csv('labellaSubmission(1).csv', index=False)
print("Successful...")
# Out:
# Successful...

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

input_dim = 13

# Create an MLP model
model1 = Sequential()
model1.add(Dense(13, input_dim=input_dim, activation='relu'))
model1.add(Dense(1, activation='relu'))  # Linear activation for regression

# Compile the model
model1.compile(optimizer='adam',
               epochs=100,
               batch_size=32,
               validation_data=(X_val, y_val),
               loss='mean_squared_error')

# Train the model
model1.fit(X_train, y_train)

# Make predictions
predictions = model1.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[241], line 2
#       1 import tensorflow as tf
# ----> 2 from tensorflow.keras.models import Sequential
#       3 from tensorflow.keras.layers import Dense
#       5 input_dim = 13
#
# ModuleNotFoundError: No module named 'tensorflow.keras'
